# %%
#----------------------------------------------------------------------------------------------------------------------------------

# Classification of credit card transactions as either "approved" or "fraudulent".
# Data wrangling and application of supervised learning techniques to find the best model and parameters.
# The target variable is the last column of the DataFrame: "+" -> approved // "-" -> fraudulent.

#----------------------------------------------------------------------------------------------------------------------------------

# %%
# import of all required libaries & data; first inspection

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("cc_approvals.data")

# %%
print(data.info(),"\n")
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   b       689 non-null    object
#  1   30.83   689 non-null    object
#  2   0.0     689 non-null    float64
#  3   u       689 non-null    object
#  4   g       689 non-null    object
#  5   w       689 non-null    object
#  6   v       689 non-null    object
#  7   1.25    689 non-null    float64
#  8   t       689 non-null    object
#  9   t.1     689 non-null    object
#  10  1       689 non-null    int64
#  11  g.1     689 non-null    object
#  12  0       689 non-null    int64
#  13  +       689 non-null    object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 75.5+ KB
# None
#    b  30.83    0.0  u  g  w  v  1.25  t t.1  1 g.1    0  +
# 0  a  58.67  4.460  u  g  q  h  3.04  t   t  6   g  560  +
# 1  a  24.50  0.500  u  g  q  h  1.50  t   f  0   g  824  +
# 2  b  27.83  1.540  u  g  w  v  3.75  t   t  5   g    3  +
# 3  b  20.17  5.625  u  g  w  v  1.71  t   f  0   s    0  +
# 4  b  32.08  4.000  u  g  m  v  2.50  t   f  0   g    0  +

# %%
# HEADERS: for more clarity headers get renamed

# %%
header_list=["f"+str(i) for i in range(1,data.shape[1])]
header_list.append("target")
data.columns=header_list
data.sample()
# Out:
#     f1     f2    f3 f4 f5  f6  f7    f8 f9 f10  f11 f12  f13 target
# 414  a  22.25  1.25  y  p  ff  ff  3.25  f   f    0   g    0      -

# %%
# DATA TYPES

# %%
#double check data types
count=0
for c in data.columns:
    prop=data[c].apply(type).unique()
    print(c,prop)
    if len(prop)>1:
        print(f"{c} is compromised")
        count+=1
    else:
        continue
if count==0:
    print("\n=> Data types across all features are consistent.")
# Out:
# f1 [<class 'str'>]
# f2 [<class 'str'>]
# f3 [<class 'float'>]
# f4 [<class 'str'>]
# f5 [<class 'str'>]
# f6 [<class 'str'>]
# f7 [<class 'str'>]
# f8 [<class 'float'>]
# f9 [<class 'str'>]
# f10 [<class 'str'>]
# f11 [<class 'int'>]
# f12 [<class 'str'>]
# f13 [<class 'int'>]
# target [<class 'str'>]
#
# => Data types across all features are consistent.

# %%
# converting "f2" into floats and identifying non-number characters
ident_mask=pd.to_numeric(data["f2"],errors="coerce").isna()
data.loc[ident_mask,"f2"].unique()
# Out:
# array(['?'], dtype=object)

# %%
# since strings only contain "?" -> conversion to NaNs -> NaNs get imputed by the mean value in the ML preprocessing step
data["f2"]=pd.to_numeric(data["f2"],errors="coerce")
data["f2"].dtypes
# Out:
# dtype('float64')

# %%
data[data["f2"].isna()]
# Out:
#     f1  f2      f3 f4 f5  f6  f7     f8 f9 f10  f11 f12   f13 target
# 82   a NaN   3.500  u  g   d   v  3.000  t   f    0   g     0      -
# 85   b NaN   0.375  u  g   d   v  0.875  t   f    0   s     0      -
# 91   b NaN   5.000  y  p  aa   v  8.500  t   f    0   g     0      -
# 96   b NaN   0.500  u  g   c  bb  0.835  t   f    0   s     0      -
# 253  b NaN   0.625  u  g   k   v  0.250  f   f    0   g  2010      -
# 285  a NaN   1.500  u  g  ff  ff  0.000  f   t    2   g   105      -
# 328  b NaN   4.000  y  p   i   v  0.085  f   f    0   g     0      -
# 444  a NaN  11.250  u  g  ff  ff  0.000  f   f    0   g  5200      -
# 449  b NaN   3.000  y  p   i  bb  7.000  f   f    0   g     1      -
# 499  b NaN   4.000  u  g   x   v  5.000  t   t    3   g  2279      +
# 514  b NaN  10.500  u  g   x   v  6.500  t   f    0   g     0      +
# 607  b NaN   0.040  y  p   d   v  4.250  f   f    0   g     0      -

# %%
# DATA CONSISTENCY

# %%
# determine number of total NaNs -> NaNs get imputed by the mean value in the ML preprocessing step
data.isna().sum()
# Out:
# f1         0
# f2        12
# f3         0
# f4         0
# f5         0
# f6         0
# f7         0
# f8         0
# f9         0
# f10        0
# f11        0
# f12        0
# f13        0
# target     0
# dtype: int64

# %%
# split data for convenient handling
num_dat=data.select_dtypes("number")
str_dat=data.select_dtypes("object")

# %%
# determine unique categorical values
for c in str_dat.columns:
    print(c,data[c].unique())
# Out:
# f1 ['a' 'b' '?']
# f4 ['u' 'y' '?' 'l']
# f5 ['g' 'p' '?' 'gg']
# f6 ['q' 'w' 'm' 'r' 'cc' 'k' 'c' 'd' 'x' 'i' 'e' 'aa' 'ff' 'j' '?']
# f7 ['h' 'v' 'bb' 'ff' 'j' 'z' '?' 'o' 'dd' 'n']
# f9 ['t' 'f']
# f10 ['t' 'f']
# f12 ['g' 's' 'p']
# target ['+' '-']

# %%
# for further practical puroposes, assume that two-letter alphabetic strings are typos (which are probably not); therefore, correcting those, too
import re
for c in str_dat.columns:
    data[c]=data[c].apply(lambda x: re.sub(r"^[a-z]{2}$",x[0],x))
    print(c,data[c].unique())
# Out:
# f1 ['a' 'b' '?']
# f4 ['u' 'y' '?' 'l']
# f5 ['g' 'p' '?']
# f6 ['q' 'w' 'm' 'r' 'c' 'k' 'd' 'x' 'i' 'e' 'a' 'f' 'j' '?']
# f7 ['h' 'v' 'b' 'f' 'j' 'z' '?' 'o' 'd' 'n']
# f9 ['t' 'f']
# f10 ['t' 'f']
# f12 ['g' 's' 'p']
# target ['+' '-']

# %%
# each fraction of "?" (in %) in each feature
count_f=(data=="?").sum()/len(data)*100
count_f
# Out:
# f1        1.741655
# f2        0.000000
# f3        0.000000
# f4        0.870827
# f5        0.870827
# f6        1.306241
# f7        1.306241
# f8        0.000000
# f9        0.000000
# f10       0.000000
# f11       0.000000
# f12       0.000000
# f13       0.000000
# target    0.000000
# dtype: float64

# %%
# identifying rows with ("?" > 1) and determing fraction (in %)
count_r=(data=="?").sum(axis=1)
(count_r[count_r>1])/data.shape[1]*100
# Out:
# 205    28.571429
# 269    28.571429
# 329    28.571429
# 455    28.571429
# 478    21.428571
# 538    14.285714
# 591    28.571429
# 600    21.428571
# 621    28.571429
# dtype: float64

# %%
# for Python practicing purposes, identification of rows with ("?">1) in an algorithmic approach:

# 1.) identify rows with "?" and determine row index to create sub dataframe
ind_list=[]
for c in str_dat.columns:
    ind_list=ind_list+list(data[data[c]=="?"].index)
ind_list=list(set(ind_list))
sub_df=data.iloc[ind_list].reset_index()

# %%
# 2.) check each cell, count the "?" row-wise and store values in a lookup dictionary
count_dic={}
for r in sub_df.index:
    count=0
    for c in sub_df.columns:
        if sub_df.loc[r,c]=="?":
            count=count+1
        else:
            continue
        count_dic[r]=count
print(count_dic)
# Out:
# {0: 1, 1: 1, 2: 4, 3: 2, 4: 1, 5: 1, 6: 1, 7: 4, 8: 4, 9: 4, 10: 4, 11: 1, 12: 3, 13: 1, 14: 3, 15: 1, 16: 4, 17: 1, 18: 1}

# %%
# 3.) identify values >1 and match corresponding key with sub dataframe in order to unlock original index
key_list=[]
for k,v in count_dic.items():
    if v>1:
        key_list.append(k)
    else:
        continue
sub_sub_df=sub_df.loc[key_list]
sorted(list(sub_sub_df.set_index("index").index))
# Out:
# [205, 269, 329, 455, 478, 538, 591, 600, 621]

# %%
# small overall fraction of "?" -> those will be transformed to NaN \ 
# and imputed by the most frequent value in the ML preprocessind step rather than left as standalone value
data.replace("?",np.nan,inplace=True)
data.isna().sum()
# Out:
# f1        12
# f2        12
# f3         0
# f4         6
# f5         6
# f6         9
# f7         9
# f8         0
# f9         0
# f10        0
# f11        0
# f12        0
# f13        0
# target     0
# dtype: int64

# %%
# checking stats on numeric data

# %%
data.describe()
# Out:
#                f2          f3          f8         f11            f13
# count  677.000000  689.000000  689.000000  689.000000     689.000000
# mean    31.569261    4.765631    2.224819    2.402032    1018.862119
# std     11.966670    4.978470    3.348739    4.866180    5213.743149
# min     13.750000    0.000000    0.000000    0.000000       0.000000
# 25%     22.580000    1.000000    0.165000    0.000000       0.000000
# 50%     28.420000    2.750000    1.000000    0.000000       5.000000
# 75%     38.250000    7.250000    2.625000    3.000000     396.000000
# max     80.250000   28.000000   28.500000   67.000000  100000.000000

# %%
# determine distribution in order to define potential ML processing steps
sns.set_style("darkgrid")
for c in num_dat.columns:
    fig,ax=plt.subplots(figsize=(5,3))
    sns.histplot(data=data,x=c,ax=ax)
    plt.tight_layout()
    plt.show()

# %%
# check visually for correlation among numeric data
sns.heatmap(num_dat.corr(),annot=True)
# Out:
# <Axes: >

# %%
# check if a coefficent above 0.8 occurs
corr_tab=num_dat.corr()
~corr_tab[(corr_tab>0.8) & (corr_tab!=1.0)].isna()
# Out:
#         f2     f3     f8    f11    f13
# f2   False  False  False  False  False
# f3   False  False  False  False  False
# f8   False  False  False  False  False
# f11  False  False  False  False  False
# f13  False  False  False  False  False

# %%
# check duplicates with assert statement
dupl=data.duplicated(subset=(data.columns.tolist()),keep=False)
assert dupl.any()==False

# %%
# conversion of string features into categories
cat_feat=data.select_dtypes("object").columns
data[cat_feat]=data[cat_feat].astype("category")
data.dtypes
# Out:
# f1        category
# f2         float64
# f3         float64
# f4        category
# f5        category
# f6        category
# f7        category
# f8         float64
# f9        category
# f10       category
# f11          int64
# f12       category
# f13          int64
# target    category
# dtype: object

# %%
# check class balance of target & evaluate accor. to threshold
balance_tab=data["target"].value_counts(normalize=True)
balance_tab
# Out:
# target
# -    0.555878
# +    0.444122
# Name: proportion, dtype: float64

# %%
balance_threshold=0.4
if (balance_tab<=balance_threshold).sum():
    print("=> Target classes considered imbalanced.")
else:
    print("=> Target classes considered balanced.")
# Out:
# => Target classes considered balanced.

# %%
# PREPROCESSING:
	# target                 > LabelEncoding
    # categorical features	 > One Hot Encoding & Imputing by the most frequent value
	# numerical features	 > PowerTransformation & Imputing by the mean value

# %%
# load libraries, define X &y, split into training & test set
from sklearn.preprocessing import PowerTransformer, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

y=data["target"]
X=data.drop("target",axis=1)

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.3,random_state=72)

# %%
# target is encoded separately
le=LabelEncoder()
y_train_prep=le.fit_transform(y_train)
y_test_prep=le.transform(y_test)

# %%
# processing of X features
cat=data.select_dtypes("category").columns.tolist()
cat.remove("target")
num=data.select_dtypes("number").columns.tolist()

prep=ColumnTransformer(transformers=[
    ("cat",Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("encoder", OneHotEncoder(drop="first", sparse_output=False,handle_unknown="ignore"))]),cat),
    ("num",Pipeline([
        ("imputer", SimpleImputer(strategy="mean")),
        ("power", PowerTransformer())]),num)])

X_train_prep=prep.fit_transform(X_train)
X_test_prep=prep.transform(X_test)

feature_names=prep.get_feature_names_out()

# %%
# MODEL SELECTION & ML APPROACH
    # RandomForestClassifer, XGBClassifier, VotingClassifier(LogisticRegression, SVM)
    # Cross Validation for finding the best estimator by evaluating metrics (ROC_AUC_SCORE)
    # Hyperparameter Tuning via RandomizedSearchCV and Optuna
    # Feature Importance, Permutation, Explainability SHAP on final model
    # PCA and Re-run dimension reduced model

# %%
# import all required modules
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import VotingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
import optuna
from sklearn.model_selection import RandomizedSearchCV

# %%
# cross validation
base_models = [("lr", LogisticRegression(solver="liblinear")), ("svc", SVC(probability=True))]
models={"RandomForestClassifier":RandomForestClassifier, 
        "XGBClassifier":xgb.XGBClassifier, 
        "VotingClassifier":VotingClassifier}
params={"RandomForestClassifier":{'n_estimators': 30}, 
        "XGBClassifier":{'n_estimators': 30}, 
        "VotingClassifier":{'estimators': base_models, "voting": "soft"}}
kf=KFold(shuffle=True,n_splits=10,random_state=87)
model_dic={}
for name in models:
    Model=models[name]
    param=params[name]
    model=Model(**param)
    cv_result=cross_val_score(model, X_train_prep, y_train_prep, cv=kf,scoring="roc_auc")
    folded_score=cv_result.mean()
    model.fit(X_train_prep,y_train_prep)
    y_pred_train=model.predict_proba(X_train_prep)
    train_score=roc_auc_score(y_train_prep,y_pred_train[:,1])
    y_pred_test=model.predict_proba(X_test_prep)
    test_score=roc_auc_score(y_test_prep,y_pred_test[:,1])
    print(f"{model.__class__.__name__}:\nCV Score: {folded_score:.3f}\t\tTraining Score: {train_score:.3f}\tTest Score: {test_score:.3f}\n")
    model_dic[model.__class__.__name__]=[folded_score,train_score,test_score] # will be used for comparision analysis later on
# Out:
# RandomForestClassifier:
# CV Score: 0.911		Training Score: 1.000	Test Score: 0.935
#
# XGBClassifier:
# CV Score: 0.916		Training Score: 1.000	Test Score: 0.934
#
# VotingClassifier:
# CV Score: 0.922		Training Score: 0.958	Test Score: 0.930

# %%
# hyperparameter tuning of the VotingClassifier: RandomizedSearchCV
base_params={"lr__C":[0.001, 0.01, 0.1, 1, 10, 100, 1000],
             "lr__penalty":["l1","l2"],
             "svc__C":[0.001, 0.01, 0.1, 1, 10, 100, 1000],
             "svc__gamma":[0.001, 0.01, 0.1, 1, 10]}
vc=VotingClassifier(**params["VotingClassifier"])
rcv=RandomizedSearchCV(vc,base_params,cv=kf,n_iter=15,scoring="roc_auc")
rcv.fit(X_train_prep, y_train_prep)
print(rcv.best_score_)
print(rcv.best_params_)
print(rcv.best_estimator_)
# Out:
# 0.9201465471931687
# {'svc__gamma': 0.1, 'svc__C': 1, 'lr__penalty': 'l1', 'lr__C': 10}
# VotingClassifier(estimators=[('lr',
#                               LogisticRegression(C=10, penalty='l1',
#                                                  solver='liblinear')),
#                              ('svc', SVC(C=1, gamma=0.1, probability=True))],
#                  voting='soft')

# %%
# evaluate potential improvement due to hyperparameter tuning
tuned_model=rcv.best_estimator_
y_test_proba=tuned_model.predict_proba(X_test_prep)
test_score_tuned=roc_auc_score(y_test_prep,y_test_proba[:,1])
print(test_score_tuned)
if test_score_tuned > model_dic["VotingClassifier"][-1]:
    print("=> Improvement due to hyperparameter tuning.")
else:
    print("=> No improvement due to hyperparameter tuning.")
# Out:
# 0.9305792972459639
# => Improvement due to hyperparameter tuning.

# %%
# hyperparameter tuning of RandomForest and XGBoost: Optuna
def objective(trial):
    classifier_name = trial.suggest_categorical("classifier", ["XGB", "RandomForest"])

    if classifier_name == "XGB":
        xgb_max_depth = trial.suggest_int("xgb_max_depth", 3,35)
        xgb_n_estimators = trial.suggest_int("xgb_n_estimators", 50,300)
        classifier_obj = xgb.XGBClassifier(
            max_depth=xgb_max_depth,
            n_estimators=xgb_n_estimators)
    else:
        rf_max_depth = trial.suggest_int("rf_max_depth", 2, 35)
        n_estimators = trial.suggest_int("n_estimators", 50, 300)
        classifier_obj = RandomForestClassifier(
            max_depth=rf_max_depth,
            n_estimators=n_estimators,
            random_state=42)

    classifier_obj.fit(X_train_prep, y_train_prep)
    preds = classifier_obj.predict_proba(X_test_prep)
    roc_auc = roc_auc_score(y_test_prep, preds[:,1])
    return roc_auc

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=100)


print("Best classifier:", study.best_params["classifier"])
print("Best hyperparameters:", study.best_params)
print("Best score:", study.best_value)
# Out:
# [I 2025-12-18 12:03:20,950] A new study created in memory with name: no-name-bee57d3e-83bd-4dd8-b749-16b09180b5a0
# [I 2025-12-18 12:03:21,061] Trial 0 finished with value: 0.9223171889838556 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 22, 'xgb_n_estimators': 124}. Best is trial 0 with value: 0.9223171889838556.
# [I 2025-12-18 12:03:21,465] Trial 1 finished with value: 0.9332383665716999 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 15, 'n_estimators': 195}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:21,654] Trial 2 finished with value: 0.9227920227920229 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 22, 'xgb_n_estimators': 286}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:21,836] Trial 3 finished with value: 0.9235517568850902 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 19, 'xgb_n_estimators': 259}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:22,170] Trial 4 finished with value: 0.9277302943969611 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 30, 'n_estimators': 143}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:22,286] Trial 5 finished with value: 0.932383665716999 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 56}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:22,630] Trial 6 finished with value: 0.9318138651471986 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 20, 'n_estimators': 197}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:22,887] Trial 7 finished with value: 0.9287274453941121 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 29, 'n_estimators': 139}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:22,946] Trial 8 finished with value: 0.9286799620132953 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 3, 'xgb_n_estimators': 89}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:23,104] Trial 9 finished with value: 0.9268755935422601 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 6, 'xgb_n_estimators': 250}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:23,584] Trial 10 finished with value: 0.909496676163343 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 2, 'n_estimators': 295}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:23,746] Trial 11 finished with value: 0.9272554605887939 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 80}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:24,199] Trial 12 finished with value: 0.9325735992402658 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 15, 'n_estimators': 209}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:24,841] Trial 13 finished with value: 0.9314814814814815 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 18, 'n_estimators': 228}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:25,395] Trial 14 finished with value: 0.932716049382716 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 19, 'n_estimators': 248}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:25,885] Trial 15 finished with value: 0.9320512820512821 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 23, 'n_estimators': 263}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:26,442] Trial 16 finished with value: 0.9269705603038937 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 5, 'n_estimators': 248}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:26,840] Trial 17 finished with value: 0.9292972459639125 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 24, 'n_estimators': 163}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:27,518] Trial 18 finished with value: 0.9324786324786325 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 296}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:27,868] Trial 19 finished with value: 0.9316714150047484 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 16, 'n_estimators': 182}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:28,105] Trial 20 finished with value: 0.9295346628679961 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 25, 'n_estimators': 112}. Best is trial 1 with value: 0.9332383665716999.
# [I 2025-12-18 12:03:28,593] Trial 21 finished with value: 0.9334283000949668 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14, 'n_estimators': 229}. Best is trial 21 with value: 0.9334283000949668.
# [I 2025-12-18 12:03:29,016] Trial 22 finished with value: 0.9327635327635327 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 233}. Best is trial 21 with value: 0.9334283000949668.
# [I 2025-12-18 12:03:29,420] Trial 23 finished with value: 0.9331433998100664 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 217}. Best is trial 21 with value: 0.9334283000949668.
# [I 2025-12-18 12:03:29,798] Trial 24 finished with value: 0.9337132003798669 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 211}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:30,149] Trial 25 finished with value: 0.9261158594491927 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 6, 'n_estimators': 179}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:30,305] Trial 26 finished with value: 0.9226020892687561 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 34, 'xgb_n_estimators': 171}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:30,819] Trial 27 finished with value: 0.9336182336182337 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 200}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:31,281] Trial 28 finished with value: 0.9335232668566001 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 7, 'n_estimators': 268}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:31,355] Trial 29 finished with value: 0.9238366571699904 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 35, 'xgb_n_estimators': 57}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:31,914] Trial 30 finished with value: 0.9280151946818613 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 6, 'n_estimators': 266}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:32,406] Trial 31 finished with value: 0.9309591642924977 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 269}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:32,788] Trial 32 finished with value: 0.919088319088319 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 3, 'n_estimators': 237}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:33,151] Trial 33 finished with value: 0.9335232668566003 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 207}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:33,440] Trial 34 finished with value: 0.9334283000949667 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 162}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:33,583] Trial 35 finished with value: 0.9247863247863247 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 12, 'xgb_n_estimators': 198}. Best is trial 24 with value: 0.9337132003798669.
# [I 2025-12-18 12:03:34,024] Trial 36 finished with value: 0.9361823361823362 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 207}. Best is trial 36 with value: 0.9361823361823362.
# [I 2025-12-18 12:03:34,387] Trial 37 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 204}. Best is trial 37 with value: 0.9368471035137702.
# [I 2025-12-18 12:03:34,784] Trial 38 finished with value: 0.9373219373219375 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 196}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:34,934] Trial 39 finished with value: 0.9225071225071226 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 29, 'xgb_n_estimators': 172}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:35,417] Trial 40 finished with value: 0.9329534662867996 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 187}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:35,809] Trial 41 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 204}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:36,146] Trial 42 finished with value: 0.93656220322887 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 160}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:36,437] Trial 43 finished with value: 0.93656220322887 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 158}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:36,757] Trial 44 finished with value: 0.9315289648622982 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 16, 'n_estimators': 139}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:37,262] Trial 45 finished with value: 0.93656220322887 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 160}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:37,591] Trial 46 finished with value: 0.9206077872744539 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 4, 'n_estimators': 131}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:37,711] Trial 47 finished with value: 0.9219373219373219 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 16, 'xgb_n_estimators': 123}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:37,984] Trial 48 finished with value: 0.9288698955365622 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 17, 'n_estimators': 109}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:38,354] Trial 49 finished with value: 0.9284425451092118 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 21, 'n_estimators': 169}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:38,670] Trial 50 finished with value: 0.9283950617283951 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 35, 'n_estimators': 151}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:38,983] Trial 51 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 153}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:39,318] Trial 52 finished with value: 0.9355175688509022 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 189}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:39,556] Trial 53 finished with value: 0.9338556505223171 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14, 'n_estimators': 124}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:39,877] Trial 54 finished with value: 0.9329534662867996 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 173}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:40,244] Trial 55 finished with value: 0.933903133903134 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 195}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:40,566] Trial 56 finished with value: 0.9293922127255461 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 15, 'n_estimators': 143}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:40,892] Trial 57 finished with value: 0.932573599240266 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 174}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:41,169] Trial 58 finished with value: 0.9296771130104464 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 18, 'n_estimators': 151}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:41,577] Trial 59 finished with value: 0.933048433048433 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 218}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:41,748] Trial 60 finished with value: 0.923931623931624 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 27, 'xgb_n_estimators': 216}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:42,086] Trial 61 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 153}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:42,369] Trial 62 finished with value: 0.9337132003798672 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 154}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:42,620] Trial 63 finished with value: 0.9338556505223171 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14, 'n_estimators': 124}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:42,985] Trial 64 finished with value: 0.9336182336182336 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 193}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:43,346] Trial 65 finished with value: 0.9294396961063627 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 180}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:43,669] Trial 66 finished with value: 0.9266856600189934 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 6, 'n_estimators': 166}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:44,112] Trial 67 finished with value: 0.9316714150047484 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 15, 'n_estimators': 221}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:44,368] Trial 68 finished with value: 0.9367521367521368 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 136}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:44,563] Trial 69 finished with value: 0.9283000949667617 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 86}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:44,765] Trial 70 finished with value: 0.931718898385565 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 7, 'n_estimators': 114}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:45,019] Trial 71 finished with value: 0.9367521367521368 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 136}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:45,284] Trial 72 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 135}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:45,473] Trial 73 finished with value: 0.9246913580246914 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 104}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:45,748] Trial 74 finished with value: 0.9299145299145298 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 143}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:45,986] Trial 75 finished with value: 0.9326685660018993 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 132}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:46,242] Trial 76 finished with value: 0.9334283000949668 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 124}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:46,438] Trial 77 finished with value: 0.9254510921177588 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 10, 'xgb_n_estimators': 298}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:46,756] Trial 78 finished with value: 0.9315289648622982 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 7, 'n_estimators': 145}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:47,126] Trial 79 finished with value: 0.9334283000949668 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 15, 'n_estimators': 202}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:47,305] Trial 80 finished with value: 0.9242165242165242 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 99}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:47,425] Trial 81 finished with value: 0.9357075023741691 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 56}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:47,667] Trial 82 finished with value: 0.932383665716999 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 131}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:47,998] Trial 83 finished with value: 0.933048433048433 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14, 'n_estimators': 182}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:48,289] Trial 84 finished with value: 0.9320037986704652 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 151}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:48,596] Trial 85 finished with value: 0.9288224121557456 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 27, 'n_estimators': 168}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:48,856] Trial 86 finished with value: 0.9328584995251661 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 133}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:49,085] Trial 87 finished with value: 0.932573599240266 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 16, 'n_estimators': 117}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:49,348] Trial 88 finished with value: 0.9366571699905034 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 139}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:49,474] Trial 89 finished with value: 0.9227920227920228 and parameters: {'classifier': 'XGB', 'xgb_max_depth': 28, 'xgb_n_estimators': 140}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:50,105] Trial 90 finished with value: 0.92659069325736 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 5, 'n_estimators': 239}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:50,416] Trial 91 finished with value: 0.9369420702754037 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 138}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:50,681] Trial 92 finished with value: 0.9300094966761633 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 13, 'n_estimators': 137}. Best is trial 38 with value: 0.9373219373219375.
# [I 2025-12-18 12:03:50,901] Trial 93 finished with value: 0.937701804368471 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 120}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:51,133] Trial 94 finished with value: 0.9276353276353275 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 9, 'n_estimators': 123}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:51,413] Trial 95 finished with value: 0.9318138651471984 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 12, 'n_estimators': 148}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:51,619] Trial 96 finished with value: 0.9294396961063629 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 10, 'n_estimators': 97}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:52,010] Trial 97 finished with value: 0.9340455840455841 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 14, 'n_estimators': 212}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:52,382] Trial 98 finished with value: 0.9368471035137702 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 202}. Best is trial 93 with value: 0.937701804368471.
# [I 2025-12-18 12:03:52,759] Trial 99 finished with value: 0.9337132003798672 and parameters: {'classifier': 'RandomForest', 'rf_max_depth': 8, 'n_estimators': 203}. Best is trial 93 with value: 0.937701804368471.
# Best classifier: RandomForest
# Best hyperparameters: {'classifier': 'RandomForest', 'rf_max_depth': 11, 'n_estimators': 120}
# Best score: 0.937701804368471

# %%
# evaluate potential improvement due to hyperparameter tuning
if study.best_value > model_dic[study.best_params["classifier"]+"Classifier"][-1]:
    print("=> Improvement due to hyperparameter tuning.")
else:
    print("=> No improvement due to hyperparameter tuning.")
# Out:
# => Improvement due to hyperparameter tuning.

# %%
# setting up the final model
final_model = RandomForestClassifier(
        max_depth=study.best_params["rf_max_depth"],
        n_estimators=study.best_params["n_estimators"])
    
final_model.fit(X_train_prep,y_train_prep)
# Out:
# RandomForestClassifier(max_depth=11, n_estimators=120)

# %%
# checking feature importance

# %%
value=final_model.feature_importances_
index=feature_names
imp_feat=pd.DataFrame(data=value, index=index).sort_values(0,ascending=False)
imp_feat["cumsum"]=imp_feat.cumsum()
most_imp_feat=imp_feat[imp_feat["cumsum"]<=0.80]
print(f"{len(most_imp_feat)} out of {len(index)} features contribute to {(most_imp_feat.iloc[-1,1])*100:.1f}%.")
# Out:
# 6 out of 33 features contribute to 74.6%.

# %%
# permutation
from sklearn.inspection import permutation_importance
result = permutation_importance(final_model, X_test_prep, y_test_prep, scoring='roc_auc')
value_perm=result["importances_mean"]
value_perm
# Out:
# array([-1.32953466e-03,  8.16714150e-04,  1.15859449e-03,  4.44089210e-17,
#         2.45014245e-03,  2.65906933e-04, -3.79867047e-05,  5.88793922e-04,
#        -1.32953466e-04,  1.89933523e-05,  1.51946819e-04, -2.08926876e-04,
#        -1.15859449e-03,  0.00000000e+00, -2.22044605e-17,  1.29154796e-03,
#         0.00000000e+00,  7.40740741e-04, -5.31813865e-04,  7.59734093e-05,
#         0.00000000e+00,  5.69800570e-05, -9.49667616e-04, -7.59734093e-05,
#         1.96353276e-01,  1.23456790e-03,  2.37416904e-03,  5.12820513e-04,
#         1.84235518e-03,  1.22317189e-02,  9.15479582e-03,  5.50807217e-03,
#         6.52421652e-03])

# %%
# result processing: clip to positive results, normalize and cumulate values to determin top features
perm_feat=pd.DataFrame(data=value_perm,index=index).sort_values(0,ascending=False)
perm_feat=perm_feat[perm_feat[0]>0]
perm_feat["norm"]=perm_feat[0]/(perm_feat[0].sum())
perm_feat["cumsum"]=perm_feat["norm"].cumsum()
perm_feat["cumsum"]
# Out:
# cat__f9_t     0.806868
# num__f3       0.857132
# num__f8       0.894751
# num__f13      0.921561
# num__f11      0.944195
# cat__f6_c     0.954263
# cat__f12_p    0.964020
# num__f2       0.971590
# cat__f6_x     0.976898
# cat__f10_t    0.981971
# cat__f4_y     0.986732
# cat__f4_u     0.990088
# cat__f7_f     0.993132
# cat__f6_f     0.995551
# cat__f12_s    0.997659
# cat__f6_d     0.998751
# cat__f6_k     0.999376
# cat__f7_j     0.999688
# cat__f7_o     0.999922
# cat__f6_j     1.000000
# cat__f5_p     1.000000
# Name: cumsum, dtype: float64

# %%
# synergy between the top five features from .feature_importances_ and permutation
top_perm_feat=set(perm_feat.index.tolist()[0:5])
top_imp_feat=set(imp_feat.index.tolist()[0:5])
top_feat_join=top_imp_feat & top_perm_feat
print(f"common top features -> {top_feat_join}")
# Out:
# common top features -> {'cat__f9_t', 'num__f11', 'num__f3', 'num__f8', 'num__f13'}

# %%
# explainability via SHAP
import shap

# prepare X data
X_test_df=pd.DataFrame(data=X_test_prep,columns=feature_names) #X_test_prep must be a DataFrame with column names
X_train_df=pd.DataFrame(data=X_train_prep,columns=feature_names) #X_train_prep must be a DataFrame with column names

# %%
# which features influence a prediction toward class 1
explainer = shap.TreeExplainer(final_model, X_train_df)
shap_values = explainer(X_test_df)
value_mean=np.abs(shap_values[:,:,1]).mean(axis=0)
sns.barplot(y=value,x=feature_names,color="black")
plt.xticks(rotation=90)
plt.ylabel("mean(|SHAP value|)")
plt.show()

# %%
# what features influence the model’s actual behaviour
explainer = shap.TreeExplainer(final_model, X_train_df)
shap_values = explainer(X_test_df)
preds = final_model.predict(X_test_prep)
new_shap_values = []
for i, pred in enumerate(preds):
    new_shap_values.append(shap_values.values[i][:,pred])#
shap_values.values = np.array(new_shap_values)
shap.plots.bar(shap_values)

# %%
# principal component analysis & dimension reduction
    # mainly for practice purposes since accor. to literature:
    # tree-based models often perform better without PCA as they handle high-dimensional data well

# %%
# inspecting variance visually on the full X dataset 
from sklearn.decomposition import PCA
pca=PCA()
X_full=np.vstack([X_train_prep,X_test_prep])
pca_model=pca.fit(X_full)
variance=pca_model.explained_variance_ratio_.cumsum()

# %%
plt.plot(range(1,pca.n_components_+1),variance)
plt.xticks(range(1,pca.n_components_+1))
plt.yticks(np.arange(0.0,1.1,0.1))
plt.xlim(1,)
plt.ylim(0,1.1)
plt.ylabel("Cumulative Variance [%]")
plt.xlabel("Principal Components")
plt.tight_layout()
plt.show()

# %%
var_threshold=0.91
print(f"{len(variance[variance<var_threshold])} components cover approx. {variance[variance<var_threshold][-1]*100:.0f}% variance")
# Out:
# 10 components cover approx. 90% variance

# %%
# re-train with reduced dimensions covering 90% variance
pca_red=PCA(n_components=0.9)
X_train_red=pca_red.fit_transform(X_train_prep)
X_test_red=pca_red.transform(X_test_prep)
final_model_red = RandomForestClassifier(
        max_depth=study.best_params["rf_max_depth"],
        n_estimators=study.best_params["n_estimators"])
final_model_red.fit(X_train_red,y_train_prep)
y_pred_red=final_model_red.predict(X_test_red)
score_red=roc_auc_score(y_test_prep,y_pred_red)
print(f"ROC-AUC score:\nafter dimensionality reduction:\t\t {score_red}\nbefore dimensionality reduction:\t {study.best_value}")
# Out:
# ROC-AUC score:
# after dimensionality reduction:		 0.8452991452991453
# before dimensionality reduction:	 0.937701804368471
